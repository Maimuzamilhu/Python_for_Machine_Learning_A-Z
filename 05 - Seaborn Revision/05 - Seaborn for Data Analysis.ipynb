# %% [markdown]
#  # Scatter Plot

# %%
import seaborn as sns
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#relplot , catplot  #relplot for numerical data ploting & catplot  for categorical data ploting
sns.relplot(x = "total_bill" , y = "tip" , data = tips)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Hue , Style and Size

# %%
sns.relplot(x = "total_bill" , y = "tip" , data = tips , hue = "smoker")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x = "total_bill" , y = "tip" , data = tips , hue = "smoker" , style = "time")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x = "total_bill" , y = "tip" , data = tips , hue = "smoker" , style = "time" , size = "size")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x = "total_bill" , y = "tip" , data = tips , style = "size")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
tips["size"].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
sns.relplot(x = "total_bill" , y = "tip" , data = tips , style ="smoker")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
tips["smoker"].value_counts()
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
sns.relplot(x = "total_bill" , y = "tip" , data = tips , size ="size" , sizes=(15,200))
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
tips["time"].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %% [markdown]
#  # Line Plot

# %%
from seaborn import relplot

# %%
from numpy.random import randn

# %%
df  = df = pd.DataFrame(dict(time = np.arange(500) , value = randn(500).cumsum()))

# %%
relplot(x = "time" , y = "value" , kind = "line" , data = df)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fmri = sns.load_dataset("fmri")
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
fig , ax = plt.subplots()
sns.relplot(x = "timepoint" , y = "signal" , kind = "line" , data = fmri )
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
relplot(x = "timepoint" , y = "signal" , kind = "line" , data = fmri , ci = False , label = "signal" , height = 4 , aspect = 2 )#aspect is weidth
plt.legend(loc = "right")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fmri[fmri["timepoint"] ==5]
# Out:
#     subject  timepoint event    region    signal
# 169     s12          5  stim  parietal  0.248138
# 184     s13          5  stim  parietal  0.252627
# 185      s6          5  stim  parietal  0.239175
# 186     s11          5  stim  parietal  0.194215
# 187     s10          5  stim  parietal  0.253871
# 188      s9          5  stim  parietal  0.381495
# 189      s8          5  stim  parietal  0.212855
# 190      s7          5  stim  parietal  0.177630
# 191      s5          5  stim  parietal  0.260057
# 192      s4          5  stim  parietal  0.460896
# 193      s3          5  stim  parietal  0.199188
# 194      s2          5  stim  parietal  0.209355
# 195      s1          5  stim  parietal  0.476055
# 196      s0          5  stim  parietal  0.175532
# 336      s1          5  stim   frontal  0.315860
# 337      s2          5  stim   frontal  0.149879
# 338      s3          5  stim   frontal  0.147985
# 339      s4          5  stim   frontal  0.455575
# 340      s5          5  stim   frontal  0.236025
# 341      s6          5  stim   frontal  0.213484
# 342      s7          5  stim   frontal  0.176161
# 343      s8          5  stim   frontal  0.042811
# 344      s9          5  stim   frontal  0.058953
# 345     s10          5  stim   frontal  0.072731
# 346     s11          5  stim   frontal  0.160735
# 347     s12          5  stim   frontal  0.091027
# 348     s13          5  stim   frontal  0.211232
# 351      s0          5  stim   frontal  0.085387
# 533      s6          5   cue  parietal  0.038145
# 534      s7          5   cue  parietal -0.008158
# 535      s8          5   cue  parietal  0.047136
# 536      s9          5   cue  parietal  0.055847
# 537     s10          5   cue  parietal  0.037892
# 540     s12          5   cue  parietal  0.047577
# 544      s4          5   cue  parietal  0.186053
# 545      s5          5   cue  parietal  0.028700
# 547      s3          5   cue  parietal  0.088904
# 548      s2          5   cue  parietal  0.007216
# 549      s1          5   cue  parietal  0.215735
# 550      s0          5   cue  parietal  0.102044
# 565     s13          5   cue  parietal  0.081027
# 580     s11          5   cue  parietal  0.042613
# 605     s13          5   cue   frontal  0.056731
# 606     s12          5   cue   frontal -0.006805
# 607     s11          5   cue   frontal  0.015301
# 608     s10          5   cue   frontal -0.008964
# 609      s9          5   cue   frontal  0.047048
# 610      s8          5   cue   frontal  0.018260
# 611      s7          5   cue   frontal -0.017946
# 612      s5          5   cue   frontal  0.035830
# 634      s2          5   cue   frontal -0.013418
# 635      s1          5   cue   frontal  0.128592
# 636      s0          5   cue   frontal  0.067086
# 655      s3          5   cue   frontal  0.080447
# 657      s4          5   cue   frontal  0.188521
# 658      s6          5   cue   frontal -0.007726

# %%
fmri[fmri["timepoint"] ==5].min()
# Out:
# subject            s0
# timepoint           5
# event             cue
# region        frontal
# signal      -0.017946
# dtype: object

# %%
relplot(x = "timepoint" , y = "signal" , kind = "line" , estimator = None , data = fmri , ci = False , label = "signal" , height = 4 , aspect = 2 )#aspect is weidth
plt.legend(loc = "right")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
relplot(x = "timepoint" , y = "signal" , kind = "line", hue = "event" ,data = fmri , ci = False , label = "signal" , height = 4 , aspect = 2 )#aspect is weidth
plt.legend(loc = "right")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
relplot(x = "timepoint" , y = "signal" , kind = "line", hue = "event" , style = "region" ,data = fmri , ci = False , label = "signal" , height = 4 , aspect = 2 )#aspect is weidth
plt.legend(loc = "right")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
relplot(x = "timepoint" , y = "signal" , kind = "line", hue = "event", marker = True , dashes = False, style = "region" ,data = fmri , ci = False , label = "signal" , height = 4 , aspect = 2 )#aspect is weidth
plt.legend(loc = "right")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   func(*plot_args, **plot_kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
dots = sns.load_dataset("dots").query("align == 'dots'")

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
relplot(x = "time" , y = "firing_rate" , data =dots)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
relplot(x = "time" , y = "firing_rate" , data =dots , kind = "line")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
relplot(x = "time" , y = "firing_rate" , data =dots , kind = "line" , hue = "coherence" , style = "choice")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
pallette = sns.cubehelix_palette(light = 0.5 , n_colors = 6)
relplot(x = "time" , y = "firing_rate" , data =dots , kind = "line" , hue = "coherence" , style = "choice")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
relplot(x = "time" , y = "firing_rate" , data =dots , kind = "line" , hue = "coherence" , style = "choice" , size = "choice")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
#  # Subplots

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
relplot(x = "total_bill" , y = "tip" , hue = "smoker" , col = "time", data = tips)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
relplot(x = "total_bill" , y = "tip" , hue = "smoker" , col = "smoker", data = tips)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
relplot(x = "total_bill" , y = "tip" , hue = "smoker" , col = "size" , data = tips)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
relplot(x = "total_bill" , y = "tip" , hue = "smoker" , col = "time" , data = tips , row = "size")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
relplot(x = "total_bill" , y = "tip" , hue = "smoker" , col = "size" , data = tips ,col_wrap =3)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
#  # Using sns.lineplot() and sns.scatterplot()

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x = "timepoint" , y = "signal" , style = "event" , hue = "region", data = fmri , markers =True , ci = 68 , err_style = "bars")
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_12612\3507960231.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   sns.lineplot(x = "timepoint" , y = "signal" , style = "event" , hue = "region", data = fmri , markers =True , ci = 68 , err_style = "bars")
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x = "timepoint" , y = "signal"  , hue = "event", data = fmri.query("region =='frontal'") , markers =True , ci = 68 , err_style = "bars")
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_12612\2902758508.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   sns.lineplot(x = "timepoint" , y = "signal"  , hue = "event", data = fmri.query("region =='frontal'") , markers =True , ci = 68 , err_style = "bars")
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x = "timepoint" , y = "signal"  , hue = "event", data = fmri.query("region =='frontal'") , markers =True , ci = 68 , err_style = "bars" , estimator = None  , lw = None)
# Out:
# C:\Users\PMLS\AppData\Local\Temp\ipykernel_12612\4239579244.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 68)` for the same effect.
#
#   sns.lineplot(x = "timepoint" , y = "signal"  , hue = "event", data = fmri.query("region =='frontal'") , markers =True , ci = 68 , err_style = "bars" , estimator = None  , lw = None)
# <Axes: xlabel='timepoint', ylabel='signal'>

# %%
sns.scatterplot(x = "total_bill" , y = "tip" , data = tips , hue = "smoker" , size = "size" , style = "time" )
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
#  # Categorical Data Ploting

# %% [markdown]
# ##### Cat Plot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x = "day" , y = "total_bill" , data = tips)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(y = "day" , x = "total_bill" , data = tips)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x = "day" , y = "total_bill" , data = tips , jitter = False)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x = "day" , y = "total_bill" , data = tips , kind = "swarm" , hue = "size")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x = "smoker" , y = "tip" , data = tips)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x = "smoker" , y = "tip" , data = tips , order = ["No" , "Yes"])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Box Plot

# %%
sns.catplot(x = "day" , y = "total_bill" , kind = "box" , data = tips , hue ="sex")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x = "day" , y = "total_bill" , kind = "box" , data = tips , hue ="sex" , dodge = False)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Boxen Plot

# %%
diamonds = sns.load_dataset("diamonds")

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.catplot(x = "color" , y = "price" , kind = "boxen" , data = diamonds)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x = "color" , y = "price" , kind = "boxen" , data = diamonds , dodge = False , hue = "cut")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Violin Plot

# %%
sns.catplot(x = "total_bill" , y = "day" , data = tips ,kind ="violin" , split = True, hue = "sex")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
g = sns.catplot(x = "day" , y = "total_bill" , data = tips , kind = "swarm" )
sns.catplot(x = "day" , y = "total_bill" , data = tips ,kind ="violin" , split = True, hue = "sex" , ax = g.ax , size = 3)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:3025: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try violinplot
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Bar Plot

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(x = "sex" , y = "survived" , kind = "bar" , data = titanic , hue ="class")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(x = "sex" , y = "survived" , kind = "bar" , data = titanic , hue ="class" , palette = "ch:0.95")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Point Plot

# %%
sns.catplot(x = "sex" , y = "survived" , hue = "class" , kind = "point" , data = titanic)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
#  # Joint Plot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
x = tips["total_bill"]
y = tips["tip"]

# %%
sns.jointplot( y)

# %%
#sns.jointplot(x, y , kind = "hex")

# %% [markdown]
# # Pair Plot

# %%
sns.pairplot(tips)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
g = sns.PairGrid(tips)
g.map_diag(sns.kdeplot)

# %%
g = sns.PairGrid(tips)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot , n_levels = 10)

# %%
g = sns.PairGrid(tips)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.scatterplot)

# %% [markdown]
#  # Regression Plot

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.regplot(x  = "total_bill" , y = "tip" , data = tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lmplot(x  = "size" , y = "tip" , data = tips , x_jitter = 0.05)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ### Controlling Ploted Figure Aesthetics
#
# ##### Figure Styling
# ##### Axes Styling
# ##### Color Palettes
# ##### etc

# %%
def sinplot(flip = 1):
    x = np.linspace(0, 14, 100)
    for i in range(1 ,7):
        plt.plot(x , np.sin(x + i*0.5)*(7-i)*flip )

# %%
sinplot()

# %%
sinplot(-1)

# %%
sns.set_style("ticks" ,{"axes.grid": True, "xticks.direction": "in"})
sinplot()
sns.despine(left = True , bottom = False)

# %%
sns.axes_style()
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': '.15',
#  'axes.grid': True,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': '.8',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': <CapStyle.round: 'round'>,
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'xtick.bottom': True,
#  'xtick.top': False,
#  'ytick.left': True,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}
